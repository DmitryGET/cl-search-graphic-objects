# %% [markdown]
# # Обучение YOLO

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load the model.
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:04<00:00, 12.5MB/s]

# %%
results = model.train(
   data='/content/drive/MyDrive/logo_dataset/data.yaml',
   epochs=25,
   batch=16,
   name='gryass'
)
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_1 = YOLO('/content/runs/detect/gryass/weights/best.pt')

# %%
model_1.predict(f'/content/dataset/test1/test_{11}.png', save=True)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
plt.imshow(cv2.imread('/content/runs/detect/gryass/results.png'))

# %%
plt.imshow(cv2.imread('/content/runs/detect/gryass/val_batch0_pred.jpg'))

# %%
model.val()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/val.cache... 420 images, 0 backgrounds, 0 corrupt: 100%|██████████| 420/420 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 27/27 [00:16<00:00,  1.64it/s]
#                    all        420        420      0.999          1      0.995      0.981
#                tinkoff        420         70      0.999          1      0.995      0.987
#                 naumen        420         70      0.999          1      0.995      0.977
#             rostelecom        420         70      0.999          1      0.995      0.978
#                   ussc        420         70      0.998          1      0.995      0.993
#                   sber        420         70      0.999          1      0.995      0.976
# ...

# %%
terminator2004.predict('/content/dataset/test/sample_1320.png', save=True)
plt.imshow(cv2.imread('/content/runs/detect/predict/sample_1320.png'))
# Out:
# image 1/1 /content/dataset/test/sample_1320.png: 640x640 1 tinkoff, 38.1ms
# Speed: 6.5ms preprocess, 38.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
